# %%
import numpy as np
# !pip install cantera CoolProp
# !pip install --no-deps git+https://github.com/davetew/Modern-Aerospace-Propulsion.git
# Out:
# Collecting cantera
#   Downloading cantera-3.2.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# Collecting CoolProp
#   Downloading coolprop-7.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: numpy<3,>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from cantera) (2.0.2)
# Collecting ruamel.yaml<1,>=0.17.21 (from cantera)
#   Downloading ruamel.yaml-0.18.16-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: typing_extensions>=4.13.0 in /usr/local/lib/python3.12/dist-packages (from cantera) (4.15.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml<1,>=0.17.21->cantera)
#   Downloading ruamel_yaml_clib-0.2.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Downloading cantera-3.2.0-cp312-cp312-manylinux_2_28_x86_64.whl (19.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 66.5 MB/s eta 0:00:00
# Downloading coolprop-7.2.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (6.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 64.9 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.16-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.9/119.9 kB 9.2 MB/s eta 0:00:00
# Downloading ruamel_yaml_clib-0.2.15-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (788 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.2/788.2 kB 42.5 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, CoolProp, ruamel.yaml, cantera
# Successfully installed CoolProp-7.2.0 cantera-3.2.0 ruamel.yaml-0.18.16 ruamel.yaml.clib-0.2.15
# Collecting git+https://github.com/davetew/Modern-Aerospace-Propulsion.git
#   Cloning https://github.com/davetew/Modern-Aerospace-Propulsion.git to /tmp/pip-req-build-ncg5nf2j
#   Running command git clone --filter=blob:none --quiet https://github.com/davetew/Modern-Aerospace-Propulsion.git /tmp/pip-req-build-ncg5nf2j
#   Resolved https://github.com/davetew/Modern-Aerospace-Propulsion.git to commit 179f6b4008c4c8c2c5e19aa1d690d66cc17992f6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: modern-aerospace-propulsion
#   Building wheel for modern-aerospace-propulsion (pyproject.toml) ... done
#   Created wheel for modern-aerospace-propulsion: filename=modern_aerospace_propulsion-0.1.0-py3-none-any.whl size=32474 sha256=6c54d3ac270faa909536a3caa282bd6ea82cd87d9f80c059b59926c99a40a10d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-j2nzjt08/wheels/77/00/ae/c5ef1a293a96c094d18bf58431724d9643772d534737428aa6
# Successfully built modern-aerospace-propulsion
# Installing collected packages: modern-aerospace-propulsion
# Successfully installed modern-aerospace-propulsion-0.1.0

# %%
def cstar(m_dot):
  p0 = 30e6
  a_t = 0.03898
  return p0*a_t / m_dot #N/m^2 * m^2/ (kg/s)

from modern_aerospace_propulsion.ffsc_nozzle import thermo, regen, cycle, sweep

# === Engine input parameters ===
OF = 3.8            # Oxidizer-to-fuel ratio, typical for CH4/O2 FFSC
p0 = 30e6           # Chamber pressure (Pa), 25 MPa

# Calculate the chamber state with Cantera
T, y, R, _ = thermo.cantera_chamber_state(OF=OF, p0=p0)

cstar_theory = np.sqrt(y*R*T)/ (y*(2/(y+1))**((y+1)/(2*y-2)))
print(cstar_theory)

n_cstar = cstar(770)/cstar_theory
print(n_cstar)
# Out:
# 1817.8942063931165
# 0.8354178661004447
